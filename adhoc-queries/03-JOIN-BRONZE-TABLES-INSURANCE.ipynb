# %%
# %sql
-- JOIN BRONZE TABLES
SELECT 
    * 
FROM susep_bronze.ses_seguros seguros --7.139.360
INNER  JOIN susep_bronze.aux_de_para_ramo_susep ramo
 on seguros.coramo = ramo.cod_ramo_susep --7.139.352 -- SOMENTE DADOS ANTIGOS SEM VALORES DE PREMIO
INNER JOIN susep_bronze.aux_de_para_grupo_empresa empresa
 on seguros.coenti = empresa.coenti -- 7.139.352
 order by rand() limit 700000
