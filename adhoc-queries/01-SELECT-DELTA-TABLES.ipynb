# %%
# %sql
SHOW TABLES IN susep

# %%
# %sql
DESCRIBE HISTORY susep.bronze_ses_campos

# %%
# %sql
select * from susep.bronze_ses_campos

# %%
# %sql
select 
    *
from susep.bronze_ses_campos

# %%
# %sql
select * from susep.bronze_ses_cias

# %%
# %sql
select * from susep.bronze_ses_dependencias

# %%
# %sql
select * from susep.bronze_ses_diversos

# %%
# %sql
select * from susep.bronze_ses_grupos_economicos

# %%
# %sql
select * from susep.bronze_ses_gruposramos

# %%
# %sql
select * from susep.bronze_ses_ramos

# %%
# %sql
select * from susep.bronze_ses_seguros

# %%
# %sql
select * from susep.bronze_ses_uf2
