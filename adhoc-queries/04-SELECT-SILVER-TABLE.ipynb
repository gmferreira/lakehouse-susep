# %%
# %sql
describe susep_silver.tb_seguro_mensal_susep

# %%
# %sql
describe susep_silver.vw_fato_seguro_mensal_susep

# %%
# %sql
select * from susep_silver.vw_fato_seguro_mensal_susep_sem_dpvat
LIMIT 700000
